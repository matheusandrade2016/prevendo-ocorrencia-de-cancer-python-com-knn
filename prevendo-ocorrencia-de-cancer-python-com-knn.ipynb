# %%
# Importando nossas Bibliotecas 

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
# Carrehando nosso dataset
dados = pd.read_csv("/kaggle/input/ocorrncia-de-cncer/dataset.csv")

# %%
# Verificando meus dados
dados.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 0          0.10280           0.06981         0.03987      0.03700  ...
# 1          0.09688           0.11470         0.06387      0.02642  ...
# 2          0.10770           0.07804         0.03046      0.02480  ...
# 3          0.11640           0.11360         0.04635      0.04796  ...
# 4          0.07963           0.06934         0.03393      0.02657  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
# Retirando minha coluna ID
# dados = dados.iloc[:,1:32]
dados = dados.drop(['id'], axis = 1)

# %%
# Mudando os valores da coluna Diagnosis usando np.where
dados.diagnosis = np.where((dados.diagnosis == 'M'), 'Maligno', 'Benigno')

# %%
# Verificando meus dados novamente
dados.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0   Benigno        12.32         12.39           78.85      464.1
# 1   Benigno        10.60         18.95           69.28      346.4
# 2   Benigno        11.04         16.83           70.92      373.2
# 3   Benigno        11.28         13.39           73.00      384.8
# 4   Benigno        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# 0          0.10280           0.06981         0.03987      0.03700
# 1          0.09688           0.11470         0.06387      0.02642
# 2          0.10770           0.07804         0.03046      0.02480
# 3          0.11640           0.11360         0.04635      0.04796
# 4          0.07963           0.06934         0.03393      0.02657
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.1959  ...         13.50          15.64            86.97
# ...

# %%
# Contando meus valores da variavel
dados.diagnosis.value_counts()
# Out:
# diagnosis
# Benigno    357
# Maligno    212
# Name: count, dtype: int64

# %%
# Medidas de Tendência Central

# Detectamos um problema de escala entre os dados, que então p
# recisam ser normalizados
(dados[['radius_mean', 'area_mean', 'smoothness_mean']]).describe()
# Out:
#        radius_mean    area_mean  smoothness_mean
# count   569.000000   569.000000       569.000000
# mean     14.127292   654.889104         0.096360
# std       3.524049   351.914129         0.014064
# min       6.981000   143.500000         0.052630
# 25%      11.700000   420.300000         0.086370
# 50%      13.370000   551.100000         0.095870
# 75%      15.780000   782.700000         0.105300
# max      28.110000  2501.000000         0.163400

# %%
# Criando nossas variaveis para a separação dos dados
X = dados.drop(['diagnosis'], axis = 1)
y = dados.diagnosis

# %%
# Criando nosso Escalonador para o teste
escalonador = StandardScaler()

# %%
# Criando um novo Datraframe
dados_normalizados = pd.DataFrame(escalonador.fit_transform(X))

# %%
# Dividindo nossos dados em treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.7, 
                                                    random_state = 0)

# %%
# Criando meu Modelo KNN
modelo_knn = KNeighborsClassifier(n_neighbors= 3)

# %%
# Fazendo meu Treinamento dos dados
modelo_knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Fazendo minhas previsões 
previsoes_knn = modelo_knn.predict(X_test)
print(previsoes_knn)
# Out:
# ['Maligno' 'Maligno' 'Benigno' 'Benigno' 'Benigno' 'Benigno' 'Benigno'
#  'Maligno' 'Benigno' 'Benigno' 'Maligno' 'Benigno' 'Benigno' 'Benigno'
#  'Benigno' 'Maligno' 'Benigno' 'Maligno' 'Benigno' 'Benigno' 'Benigno'
#  'Benigno' 'Maligno' 'Maligno' 'Benigno' 'Benigno' 'Benigno' 'Maligno'
#  'Benigno' 'Benigno' 'Benigno' 'Benigno' 'Benigno' 'Benigno' 'Maligno'
#  'Maligno' 'Benigno' 'Benigno' 'Benigno' 'Benigno' 'Benigno' 'Maligno'
#  'Maligno' 'Benigno' 'Benigno' 'Benigno' 'Benigno' 'Benigno' 'Maligno'
#  'Benigno' 'Benigno' 'Maligno' 'Benigno' 'Benigno' 'Benigno' 'Maligno'
#  'Benigno' 'Maligno' 'Benigno' 'Benigno' 'Maligno' 'Benigno' 'Maligno'
#  'Benigno' 'Benigno' 'Benigno' 'Benigno' 'Benigno' 'Benigno' 'Benigno'
#  'Benigno' 'Benigno' 'Benigno' 'Benigno' 'Maligno' 'Benigno' 'Benigno'
#  'Benigno' 'Benigno' 'Benigno' 'Maligno' 'Benigno' 'Maligno' 'Benigno'
#  'Benigno' 'Maligno' 'Benigno' 'Benigno' 'Maligno' 'Benigno' 'Benigno'
# ...

# %%
# Verificando minha acuracia
acuracia_modelo = accuracy_score(y_test, previsoes_knn)
print()
print(f"Acuaraica do Modelo : {acuracia_modelo:.2f}%")
# Out:
# Acuaraica do Modelo : 0.93%
